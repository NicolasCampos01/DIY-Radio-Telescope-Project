# %% [markdown]
# Analizar los espectros tomados desde dentro la galaxia para medir la curva de rotación.
# use gausspy to fit multiple gaussians (https://gausspy.readthedocs.io/en/latest/index.html)

# %%
# !git clone https://github.com/gausspy/gausspy.git
# Out:
# Cloning into 'gausspy'...
# remote: Enumerating objects: 5213, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 5213 (delta 38), reused 16 (delta 8), pack-reused 5144
# Receiving objects: 100% (5213/5213), 23.21 MiB | 18.99 MiB/s, done.
# Resolving deltas: 100% (2616/2616), done.

# %%
# %cd gausspy
# !pip install .
# Out:
# /content/gausspy
# Processing /content/gausspy
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: astropy in /usr/local/lib/python3.10/dist-packages (from gausspy==1.0) (5.3.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gausspy==1.0) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gausspy==1.0) (1.11.4)
# Collecting lmfit (from gausspy==1.0)
#   Downloading lmfit-1.2.2-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from gausspy==1.0) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gausspy==1.0) (4.66.1)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy->gausspy==1.0) (2.0.1.1)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy->gausspy==1.0) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy->gausspy==1.0) (23.2)
# Collecting asteval>=0.9.28 (from lmfit->gausspy==1.0)
#   Downloading asteval-0.9.31-py3-none-any.whl (20 kB)
# Collecting uncertainties>=3.1.4 (from lmfit->gausspy==1.0)
#   Downloading uncertainties-3.1.7-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gausspy==1.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gausspy==1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gausspy==1.0) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gausspy==1.0) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gausspy==1.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gausspy==1.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gausspy==1.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->gausspy==1.0) (1.16.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from uncertainties>=3.1.4->lmfit->gausspy==1.0) (0.18.3)
# Building wheels for collected packages: gausspy
#   Building wheel for gausspy (setup.py) ... done
#   Created wheel for gausspy: filename=gausspy-1.0-py3-none-any.whl size=30485 sha256=3cf5a7c99a0967bcc2de732db2541a53b9b8208bff7c64dc26bb42161fbba0e9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nj9l53em/wheels/73/0d/2c/2e638da1d640eac40015b6aa451a76b3f618da49790035f04d
# Successfully built gausspy
# Installing collected packages: uncertainties, asteval, lmfit, gausspy
# Successfully installed asteval-0.9.31 gausspy-1.0 lmfit-1.2.2 uncertainties-3.1.7

# %%
import matplotlib.pyplot as plt
import numpy as np
import os, glob
import math
import pickle
import gausspy.gp as gp
# import plot_params
# %matplotlib inline

# %%
def gaussian(amp, fwhm, mean):
    return lambda x: amp * np.exp(-4. * np.log(2) * (x-mean)**2 / fwhm**2)

def unravel(list):
    return np.array([i for array in list for i in array])

# %%
# set the same for all spectra here
g = gp.GaussianDecomposer()

# Setting AGD parameters
g.set('phase', 'two')
g.set('alpha1' , 1.25)
g.set('alpha2' , 2.5)
g.set('SNR_thresh', 3)
g.set('SNR2_thresh', 3)

# %%
# go to directory with the reduced data
path = '/content/drive/MyDrive/Python/reduced_spectra'
os.chdir(path)
cwd = os.getcwd()

# %%
# Galactocentric distance and rotation velocity
Rsun = 8.2   # kpc
Vsun = 220   # km/s

# %%
# create an ordered list of longitudes
lon = []
for f in os.listdir():
    if f[0:3]=='lon' and f[-3:]=='csv':
        l = int(f[3:5])
        lon.append(l)
lon.sort()

# %%
n = len(lon)
nx = 3
ny = math.ceil(n/nx)
sx = 20
sy = 0.5 * sx * ny / nx
fig = plt.figure(figsize=(sx,sy))

# plot a single position for the title page of the instruction guide
#lon = [30]
#n = nx = ny = 1
#fig = plt.figure(figsize=(12,3))

R1 = np.zeros(n)
vmax1 = np.zeros(n)
vrot1 = np.zeros(n)
for i,l in enumerate(lon):
    ax = fig.add_subplot(ny, nx, i+1)
    #fig = plt.figure(figsize=(10,7))
    #ax = fig.add_subplot(111)
    v, T = np.genfromtxt('lon'+str(l)+'_reduced.csv', delimiter=',', unpack=True)

    crop = (v > -200) & (v < 200)
    v = v[crop]
    T = T[crop]
    ax.plot(v, T, color='blue', lw=3, zorder=0)
    ax.text(0.05, 0.85, str('lon = {0}'.format(l)), fontsize=12, transform=ax.transAxes)
    if i==6:
        ax.set_xlabel(r'$V_{\rm LSR}$ (km/s)')
        ax.set_ylabel(r'$T_{\rm B}$ (K)')

    # write it out in the format that gausspy wants to process
    pfile = 'lon'+str(l)+'.pickle'
    nchan = T.size
    rms = 1
    data = {}
    chan = np.arange(nchan)
    errors = np.ones(nchan) * rms

    data['data_list'] = data.get('data_list', []) + [T]
    data['x_values'] = data.get('x_values', []) + [chan]
    data['errors'] = data.get('errors', []) + [errors]
    pickle.dump(data, open(pfile, 'wb'))

    # run GaussPy
    # (note that it works on a pickle file which is why we have to write one out and then read it back in...)
    data_decomp = g.batch_decomposition(pfile)
    means_fit = unravel(data_decomp['means_fit'])
    amps_fit = unravel(data_decomp['amplitudes_fit'])
    fwhms_fit = unravel(data_decomp['fwhms_fit'])

    # plot the gaussian decomposition components
    model = np.zeros(len(chan))
    mu_max = -9999
    print('------------------------')
    print('lon = {0}     R = {1:4.1f}'.format(l, Rsun * np.sin(l * np.pi / 180)))
    print('------------------------')
    print('  Amp     FWHM     Mean')
    for j in range(len(means_fit)):
        A = amps_fit[j]
        fwhm = fwhms_fit[j]
        mu = means_fit[j]
        print('{0:6.1f}   {1:6.1f}   {2:6.1f}'.format(A,fwhm,mu))
        component = gaussian(A, fwhm, mu)(chan)
        model += component
        ax.plot(v, component, color='red', lw=1.5)
        if (A > 0) & (fwhm < 200) & (mu > mu_max):
            mu_max = mu
    ax.plot(v, model, color='purple', lw=5, alpha=0.5, zorder=99)
    print('------------------------')

    R1[i] = Rsun * np.sin(l * np.pi / 180)
    kmax = int(mu_max)
    vm = v[kmax]

    # Shane & Bieger-Smith 1966 correction
    dv = v[1] - v[0]
    vmax1[i] = vm + dv*np.sum(T[kmax:])/T[kmax] - dv/2
    vrot1[i] = (vmax1[i]/np.sin(l*np.pi/180) + Vsun)*R1[i]/Rsun
    print('Vm ={0:6.1f}  Vmax ={1:6.1f}  Vrot ={2:6.1f}'.format(vm, vmax1[i], vrot1[i]))
# Out:
# using 1 out of 2 cpus
#    ---->   0
# 0it [00:00, ?it/s]
# SUCCESS
# 100 finished.%
# ------------------------
# lon = 10     R =  1.4
# ------------------------
#   Amp     FWHM     Mean
#    6.8    118.3    419.6
#   25.6     58.7    395.2
#    2.8    323.8    434.9
# ------------------------
# Vm =  15.9  Vmax =  39.7  Vrot =  77.9
# using 1 out of 2 cpus
#    ---->   0
# 0it [00:00, ?it/s]
# SUCCESS
# 100 finished.%
# ------------------------
# lon = 20     R =  2.8
# ------------------------
#   Amp     FWHM     Mean
#    6.5    112.0    414.3
#    7.6    232.5    440.8
#   23.2     46.5    402.2
# ------------------------
# Vm =  13.8  Vmax =  43.0  Vrot = 118.3
# using 1 out of 2 cpus
#    ---->   0
# 0it [00:00, ?it/s]
# SUCCESS
# 100 finished.%
# ------------------------
# lon = 30     R =  4.1
# ------------------------
#   Amp     FWHM     Mean
#   13.0    160.3    457.0
#   24.1    -44.8    404.5
#    4.1     64.5    301.6
# ------------------------
# Vm =  35.9  Vmax =  75.3  Vrot = 185.3
# using 1 out of 2 cpus
#    ---->   0
# 0it [00:00, ?it/s]
# SUCCESS
# 100 finished.%
# ------------------------
# lon = 40     R =  5.3
# ------------------------
#   Amp     FWHM     Mean
#   11.6    162.1    439.8
#   16.2     23.8    399.8
#   11.2    -38.2    426.7
# ------------------------
# Vm =  26.5  Vmax =  52.8  Vrot = 194.2
# using 1 out of 2 cpus
#    ---->   0
# 0it [00:00, ?it/s]
# SUCCESS
# 100 finished.%
# ------------------------
# lon = 50     R =  6.3
# ------------------------
#   Amp     FWHM     Mean
#    7.1    126.7    426.0
#   17.5     44.5    417.4
#    3.3     74.4    267.1
# ------------------------
# Vm =  19.2  Vmax =  36.0  Vrot = 204.5
# using 1 out of 2 cpus
#    ---->   0
# 0it [00:00, ?it/s]
# SUCCESS
# 100 finished.%
# ------------------------
# lon = 60     R =  7.1
# ------------------------
#   Amp     FWHM     Mean
#   12.4     25.8    414.2
#   15.4     68.7    406.3
#    3.2    114.7    273.8
# ------------------------
# Vm =  13.7  Vmax =  24.1  Vrot = 214.6
# using 1 out of 2 cpus
#    ---->   0
# 0it [00:00, ?it/s]
# SUCCESS
# 100 finished.%
# ------------------------
# lon = 70     R =  7.7
# ------------------------
#   Amp     FWHM     Mean
#   15.5     26.8    409.8
#   12.3     61.1    395.1
#    4.2    157.8    304.5
# ------------------------
# Vm =  11.0  Vmax =  18.4  Vrot = 225.2
# using 1 out of 2 cpus
#    ---->   0
# 0it [00:00, ?it/s]
# SUCCESS
# 100 finished.%
# ------------------------
# lon = 80     R =  8.1
# ------------------------
#   Amp     FWHM     Mean
#   18.4     40.3    401.7
#    7.7    163.4    330.4
# ------------------------
# Vm =   7.1  Vmax =  20.8  Vrot = 237.5
# using 1 out of 2 cpus
#    ---->   0
# 0it [00:00, ?it/s]
# SUCCESS
# 100 finished.%
# ------------------------
# lon = 90     R =  8.2
# ------------------------
#   Amp     FWHM     Mean
#   21.6     42.2    395.9
#   12.5    117.8    316.6
# ------------------------
# Vm =   3.6  Vmax =  13.9  Vrot = 233.9

# %%
# radial velocity vs radius
plt.plot(R1, vmax1, 'bo')
plt.xlabel('R (kpc)')
plt.ylabel('Vr (km/s)')
# Out:
# Text(0, 0.5, 'Vr (km/s)')

# %%
from astropy import constants as c
from astropy import units as u
R = 8200 *  u.pc
V = 220 * u.km / u.s
M = R * V**2 / c.G
M_solar_masses = (M/u.Msun).decompose()
print('Dynamical mass = {0:5.1e} Msun'.format(M_solar_masses))
# Out:
# Dynamical mass = 9.2e+10 Msun

# %%
# rotation curve
fig = plt.figure(figsize=(12,7))
ax = fig.add_subplot(111)
ax.plot(R1, vrot1, 'bo', ms=12, alpha=0.5, label='l < 90')
#ax.legend(fontsize=12)
ax.set_xlabel(r'$R$ (kpc)', fontsize=16)
ax.set_ylabel(r'$V_{rot}$ (km/s)', fontsize=16)
plt.savefig('rotation_curve.png')
